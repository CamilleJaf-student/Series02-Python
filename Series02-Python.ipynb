# %% [markdown]
# # Series02

# %% [markdown]
# ### Add a Markdown cell with the maths to generate a sine wave

# %% [markdown]
#  y(t)= A ⋅ sin(ωt+φ)
#
#  y(t) : displacement, unit meter [m]
#
# A : amplitude, unit meter [m]
#
# ω : angular frequency, unit radian per second [rad·s⁻¹]
#
# t : time, unit second [s]
#
# φ : phase shift, unit radian [rad]
# Whole equation unit: meter [m]

# %% [markdown]
# > Create a new code cell in the notebook, in which you will:
#
# Import the needed libraries
#
# Create a numpy array called t that contains 1000 values from 0 to 1 (t is for time)
#
# Create a numpy array called s that contains the values of a sine function of t (s is for signal)
#
# Plot s as a function of t
#
# Add a title to the plot
#
# Add a label to the x axis
#
# Add a label to the y axis
#
# Add a grid to the plot
#
# Save the plot as a png file

# %%
# import libraries for generate sine function
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Create numpy array named t with 1000 values from 0 to 1
t = np.linspace(0, 1, 1000)

# Create numpy array named s that contains values of a sine function of t (s is for signal)
s = np.sin(2 * np.pi * t) 

# Plot s as a function of t and save it as a png file
plt.plot(t, s)
plt.title('Sine function')
plt.xlabel('Time [s]')
plt.ylabel('Amplitude')
plt.grid()
plt.show()
plt.savefig('sine_function_with_noise.png')

# %% [markdown]
# > 1.2. Create a notebook to plot sinusoidal signals (better version)
#
# Check whether your commit history is understandable, with clear commit messages, and whether your code is clean and well-documented. If not, improve it and commit the changes.
#
# Create a new branch in your Git repository
#
# Improve the previous notebook by adding the following features:
#
# Add a second plot of a cosine function of t in the same figure
#
# Add a legend to the plot
#
# Add a second y axis to the plot
#
# Add a second label to the y axis
#
# Save the plot as a pdf file

# %% [markdown]
# cosine function
#
# y(t) = A⋅sin(ωt+φ+2π​)

# %%
# import libraries for generate sine function
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Create numpy array named t with 1000 values from 0 to 1
t = np.linspace(0, 1, 1000)

# Create numpy array named s that contains values of a sine function of t (s is for signal)
sine = np.sin(2 * np.pi * t) 

# Create numpy array named s that contains values of a cosine function of t (s is for signal)
cosine = np.cos(2 * np.pi * t)

# Plot s as a function of t and save it as a png file
plt.plot(t, sine)
plt.plot(t, cosine)
plt.title('Sine function')
plt.xlabel('Time [s]')
plt.ylabel('Amplitude')
plt.grid()
plt.show()
plt.savefig('sine_function_with_noise.png')

# %% [markdown]
# > 1.3. Create a notebook to plot sinusoidal signals (final version)
#
# Check whether your previous commit history is OK your code is clean. If not, improve it and commit the changes.
#
# Create a new branch in your Git repository
#
# Improve the previous notebook with a better organization of the code:
#
# Create a function called sinusoid that :
# takes as input all parameters that you need to define the sinusoid
# returns a numpy array called x
#
# Use the function sinusoid to create two numpy arrays s1 and s2 with the two different frequencies
#
# Plot s1 and s2 as a function of t (as illustrated in the graph below).
#
# Improve your code so that it follows the best practices for quality of code for researchers. Focus on:
#
# ** meaningful variable names everywhere
#
# ** comments to explain why you do something (not what you do, which should be clear from the code itself)
#
# **docstrings for all functions
#
# ** references to the sources you used (web pages, books, articles, prompts to which AI, etc.). You can use a Markdown cell at the end of the notebook for this (as in a bibliography of a thesis), or comments in the code (e.g. # from: ...).

# %%
# import libraries for generate sine function
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Parameters
A = 1       # Amplitude
T = 2.0   # Period
ω = 2 * np.pi / T  # Angular frequency
φ = 0       # Phase

# Create numpy array named t with 1000 values from 0 to 1
t = np.linspace(0, 1, 1000)

# Create a function to generate a sine wave
def generate_sine_wave(t, A, ω, φ):
    return A * np.sin(ω * t + φ)

# Define s1 and s2 using the function
# s1 has a period of 1 second, s2 has a period of 2
sine1 = generate_sine_wave(t, A, 2 * np.pi / 1, φ)
sine2 = generate_sine_wave(t, A, 2 * np.pi / 0.5, φ)

# Create numpy array named s that contains values of a cosine function of t (s is for signal)
cosine = np.cos(2 * np.pi * t)

# Plot s as a function of t and save it as a png file with the name related to color use
plt.plot(t, sine1, label= "sine1")
plt.plot(t, sine2, label="sine2")
plt.title('Sine function')
plt.legend()
plt.xlabel('Time [s]')
plt.ylabel('Amplitude')
plt.grid()
plt.show()
plt.savefig('sine_function_s1_and_s2.png')
